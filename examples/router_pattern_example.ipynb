# %% [markdown]
# # Router Pattern
#
# Runnable router example using TypedDict state, reducers, structured routing, and Command-based control flow.
#
# - Default notebook mode: `stub`
# - Switch `MODE` to `live` only when credentials are configured.

# %%
MODE = "stub"
MODEL = "gpt-4.1-mini"
TASK = "Search the docs and summarize when Command is preferable to conditional edges."

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "src").exists():
    ROOT = ROOT.parent
for path in (ROOT, ROOT / "src"):
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

from examples.router_pattern_example import run_demo

RESULT = run_demo(TASK, mode=MODE, model=MODEL)
RESULT
