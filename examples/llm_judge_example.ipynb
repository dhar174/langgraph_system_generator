# %% [markdown]
# # LLM-as-a-Judge
#
# Rubric-based scoring example showing how judge feedback can gate finalization or trigger another revision cycle.
#
# - Default notebook mode: `stub`
# - Switch `MODE` to `live` only when credentials are configured.

# %%
MODE = "stub"
MODEL = "gpt-4.1-mini"
TASK = "Answer when to use router, supervisor, and reflection patterns in LangGraph."

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "src").exists():
    ROOT = ROOT.parent
for path in (ROOT, ROOT / "src"):
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

from examples.llm_judge_example import run_demo

RESULT = run_demo(TASK, mode=MODE, model=MODEL)
RESULT
