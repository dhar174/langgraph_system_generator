# %% [markdown]
# # LLMCompiler-Style Execution
#
# Dependency-graph planning example using Send fan-out and reducer-backed joins.
#
# - Default notebook mode: `stub`
# - Switch `MODE` to `live` only when credentials are configured.

# %%
MODE = "stub"
MODEL = "gpt-4.1-mini"
MAX_PARALLEL = 2
TASK = "Compile a short recommendation on when to use dependency-graph execution in LangGraph."

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "src").exists():
    ROOT = ROOT.parent
for path in (ROOT, ROOT / "src"):
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

from examples.llm_compiler_example import run_demo

RESULT = run_demo(TASK, mode=MODE, model=MODEL, max_parallel=MAX_PARALLEL)
RESULT
