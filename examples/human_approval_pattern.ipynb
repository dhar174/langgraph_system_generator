# %% [markdown]
# # Human Approval Pattern
#
# Interrupt-driven approval workflow with approve, edit, and reject paths plus an audit trail.
#
# - Default notebook mode: `stub`
# - Switch `MODE` to `live` only when credentials are configured.

# %%
MODE = "stub"
DECISION = "edit"
TASK = "Send a customer-facing status update about a delayed rollout."

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "src").exists():
    ROOT = ROOT.parent
for path in (ROOT, ROOT / "src"):
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

from examples.human_approval_pattern import run_demo

RESULT = run_demo(TASK, decision=DECISION)
RESULT
