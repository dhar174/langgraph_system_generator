# %% [markdown]
# # Hierarchical Teams
#
# Team-of-teams example with a top-level supervisor delegating to nested team graphs.
#
# - Default notebook mode: `stub`
# - Switch `MODE` to `live` only when credentials are configured.

# %%
MODE = "stub"
MODEL = "gpt-4.1-mini"
TASK = "Produce a concise explanation of when to use a team-of-teams LangGraph workflow."

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "src").exists():
    ROOT = ROOT.parent
for path in (ROOT, ROOT / "src"):
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

from examples.hierarchical_teams_example import run_demo

RESULT = run_demo(TASK, mode=MODE, model=MODEL)
RESULT
