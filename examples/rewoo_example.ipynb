# %% [markdown]
# # REWOO-Style Speculation
#
# Speculative reasoning example that predicts tool outputs, observes real results, and reconciles divergence.
#
# - Default notebook mode: `stub`
# - Switch `MODE` to `live` only when credentials are configured.

# %%
MODE = "stub"
MODEL = "gpt-4.1-mini"
TASK = "Speculate on the best pattern for a multi-agent workflow and then reconcile with observed tool outputs."

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "src").exists():
    ROOT = ROOT.parent
for path in (ROOT, ROOT / "src"):
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

from examples.rewoo_example import run_demo

RESULT = run_demo(TASK, mode=MODE, model=MODEL)
RESULT
